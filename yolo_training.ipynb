# %%
import os
os.chdir('/content/drive/MyDrive/yolo_train')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# yolo_training.ipynb  yolov5/

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17611, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 17611 (delta 13), reused 7 (delta 7), pack-reused 17589 (from 2)
# Receiving objects: 100% (17611/17611), 16.89 MiB | 13.00 MiB/s, done.
# Resolving deltas: 100% (11987/11987), done.

# %%
os.chdir('yolov5')

# %%
# !ls
# Out:
# benchmarks.py	 data_images  LICENSE	      README.zh-CN.md	tutorial.ipynb
# CITATION.cff	 data.yaml    models	      requirements.txt	utils
# classify	 detect.py    __pycache__     runs		val.py
# CONTRIBUTING.md  export.py    pyproject.toml  segment		yolov5s.pt
# data		 hubconf.py   README.md       train.py

# %% [markdown]
# ### Install all required packages from requriments.tx

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 32.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### **Training YOLO V5 Model**

# %%
# !python train.py --data data.yaml --weights yolov5s.pt --img 640 --batch-size 8 --name Model --epochs 50
# !python train.py --data data.yaml --weights yolov5s.pt --batch-size 8 --name Model --img 640 --epochs 150
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#       45/49      3.05G     0.0299    0.02879   0.006419         73        640:   7% 37/502 [00:12<02:59,  2.59it/s]/content/drive/MyDrive/yolo_train/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       45/49      3.05G    0.02987    0.02877   0.006435         39        640:   8% 38/502 [00:12<03:16,  2.36it/s]/content/drive/MyDrive/yolo_train/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# Resume the model training
#!python train.py --data data.yaml --weights runs/train/Model/weights/best.pt --img 640 --batch-size 8 --name Model --epochs 50

# %% [markdown]
# ### Export Model into onnx file

# %%
 # !python export.py --weights runs/train/Model/weights/best.pt --include onnx --simplify --opset 12
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/Model/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=True, mlmodel=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v7.0-441-g15c0127a Python-3.12.12 torch-2.8.0+cu126 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
#
# PyTorch: starting from runs/train/Model/weights/best.pt with output shape (1, 25200, 25) (13.8 MB)
#
# ONNX: starting export with onnx 1.19.1...
# ...
